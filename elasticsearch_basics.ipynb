# %%
import json
import logging
import elasticsearch
from elasticsearch import helpers

# %%
def connect_elasticssearch():
    config = {
        'host': 'localhost',
        'port': '9200'
    }
    _es = elasticsearch.Elasticsearch([config,], timeout=300)
    if _es.ping():
        print('Conectado!')
    else:
        print('Não há conexão com o Elasticsearch')
    return _es

if __name__ == '__main__':
  logging.basicConfig(level=logging.ERROR)

# %%
def create_index(es_object, index_name):
    created = False
    #index settings
    settings = {
        "settings":{
            "number_of_shards": 1,
            "number_of_replicas": 0
        }
    }
    
    try:
        if not es_object.indices.exists(index_name):
                # Ignore 400 means to ignore "Index Already Exist" error.
                es_object.indices.create(index=index_name, body=settings)
                print('Created Index')
        created = True
    except Exception as ex:
        print(str(ex))
    finally:
            return created

# %%
def get_indices(es_object):
    return es_object.indices.get_alias("*")

# %%
def delete_all_indices(es_object):
    
    for key in es_object.indices.get_alias("*").keys():
        es_object.indices.delete(index=key)

# %%
def get_data_from_file(filename):
    data = [l.strip() for l in open(filename, encoding="utf8", errors='ignore')]
    return data

# %%
def bulk_insert_from_file(es_object, filename):
    data = get_data_from_file(filename)
    response = helpers.bulk(es_object, 
                            data,
                            index = 'accounts',
                            doc_type = '_doc'
                           )

# %%
def get_all_documents(es_object, index_name, size):
    
    body = {
        'size': size,
        'query': {
            'match_all': {}
            },
        'sort': [{ 'account_number': 'asc' }] 
    }

    response = es_object.search(index = index_name, doc_type = '_doc', body = body)

    return [doc for doc in response['hits']['hits']]

# %%
def get_n_documents(es_object, index_name, size, start):
    body = {
        'query': {
            'match_all': {}
        },
        'sort': [{'account_number': 'asc'}],
        'from': start,
        'size': size
    }
    
    response = es_object.search(index = index_name, doc_type = '_doc', body = body)
    
    return [doc for doc in response['hits']['hits']]

# %%
def get_document_by_address(es_object, index_name, address):
    body = {
        'query':{
            'match':{
                'address': address
            }
        }
    }
    
    response = es_object.search(index = index_name, body = body)
    
    return [doc for doc in response['hits']['hits']]

# %%
def get_document_by_address_strict(es_object, index_name, address):
    body = {
        'query':{
            'match_phrase':{
                'address': address
            }
        }
    }
    
    response = es_object.search(index = index_name, body = body)
    
    return [doc for doc in response['hits']['hits']]

# %%
def get_document_by_age_and_state(es_object, index_name, age, state):
    body = {
        'query': {
            'bool': {
                'must': [
                    {
                        'match' : {'age': age}
                    }
                ],
                'must_not': [
                    {'match': {'state': state}}
                ]
            }
        }
    }
    
    response = es_object.search(index = index_name, body = body)
    return [doc for doc in response['hits']['hits']]

# %%
def get_documents_in_balance_range(es_object, index_name, gte, lte):
    body = {
        'query': {
            'bool': {
                'must': {
                    'match_all': {}
                },
                'filter': {
                    'range':{
                        'balance':{
                            'gte': gte,
                            'lte': lte
                        }
                    }
                }
            } 
        }
    }
    
    response = es_object.search(index = index_name, body = body)
    return [doc for doc in response['hits']['hits']]

# %%
def aggregate_accounts_by_state(es_object, index_name):
    body = {
        'size': 0,
        'aggs': {
            'group_by_state': {
                'terms': {
                    'field': 'state.keyword'
                }
            }
        }
    }
    
    response = es_object.search(index = index_name, body = body)
    print(response)
    return response['aggregations']['group_by_state']

# %%
es_object = connect_elasticssearch()
# Out:
# Conectado!

# %%
create_index(es_object, 'accounts')
# Out:
# Created Index
# True

# %%
get_indices(es_object)
# Out:
# {'accounts': {'aliases': {}}}

# %%
bulk_insert_from_file(es_object, 'accounts.json')

# %%
get_all_documents(es_object, "accounts", 1000)
# Out:
# [{'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '4XRYanQBXWwj1NjsoQA7',
#   '_score': None,
#   '_source': {'account_number': 0,
#    'balance': 16623,
#    'firstname': 'Bradshaw',
#    'lastname': 'Mckenzie',
#    'age': 29,
#    'gender': 'F',
#    'address': '244 Columbus Place',
#    'employer': 'Euron',
#    'email': 'bradshawmckenzie@euron.com',
#    'city': 'Hobucken',
#    'state': 'CO'},
#   'sort': [0]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'snRaanQBXWwj1Njsbwhf',
#   '_score': None,
#   '_source': {'account_number': 0,
#    'balance': 16623,
#    'firstname': 'Bradshaw',
#    'lastname': 'Mckenzie',
#    'age': 29,
#    'gender': 'F',
#    'address': '244 Columbus Place',
#    'employer': 'Euron',
#    'email': 'bradshawmckenzie@euron.com',
#    'city': 'Hobucken',
#    'state': 'CO'},
#   'sort': [0]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'gnRfanQBXWwj1Njs_hCW',
#   '_score': None,
#   '_source': {'account_number': 0,
#    'balance': 16623,
#    'firstname': 'Bradshaw',
#    'lastname': 'Mckenzie',
#    'age': 29,
#    'gender': 'F',
#    'address': '244 Columbus Place',
#    'employer': 'Euron',
#    'email': 'bradshawmckenzie@euron.com',
#    'city': 'Hobucken',
#    'state': 'CO'},
#   'sort': [0]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'UnRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 0,
#    'balance': 16623,
#    'firstname': 'Bradshaw',
#    'lastname': 'Mckenzie',
#    'age': 29,
#    'gender': 'F',
#    'address': '244 Columbus Place',
#    'employer': 'Euron',
#    'email': 'bradshawmckenzie@euron.com',
#    'city': 'Hobucken',
#    'state': 'CO'},
#   'sort': [0]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'MXNYanQBXWwj1Njsnvzq',
#   '_score': None,
#   '_source': {'account_number': 1,
#    'balance': 39225,
#    'firstname': 'Amber',
#    'lastname': 'Duke',
#    'age': 32,
#    'gender': 'M',
#    'address': '880 Holmes Lane',
#    'employer': 'Pyrami',
#    'email': 'amberduke@pyrami.com',
#    'city': 'Brogan',
#    'state': 'IL'},
#   'sort': [1]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'AnRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 1,
#    'balance': 39225,
#    'firstname': 'Amber',
#    'lastname': 'Duke',
#    'age': 32,
#    'gender': 'M',
#    'address': '880 Holmes Lane',
#    'employer': 'Pyrami',
#    'email': 'amberduke@pyrami.com',
#    'city': 'Brogan',
#    'state': 'IL'},
#   'sort': [1]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '0nRfanQBXWwj1Njs_QvY',
#   '_score': None,
#   '_source': {'account_number': 1,
#    'balance': 39225,
#    'firstname': 'Amber',
#    'lastname': 'Duke',
#    'age': 32,
#    'gender': 'M',
#    'address': '880 Holmes Lane',
#    'employer': 'Pyrami',
#    'email': 'amberduke@pyrami.com',
#    'city': 'Brogan',
#    'state': 'IL'},
#   'sort': [1]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'onRganQBXWwj1NjsHhP4',
#   '_score': None,
#   '_source': {'account_number': 1,
#    'balance': 39225,
#    'firstname': 'Amber',
#    'lastname': 'Duke',
#    'age': 32,
#    'gender': 'M',
#    'address': '880 Holmes Lane',
#    'employer': 'Pyrami',
#    'email': 'amberduke@pyrami.com',
#    'city': 'Brogan',
#    'state': 'IL'},
#   'sort': [1]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'wXNYanQBXWwj1Njsnv3t',
#   '_score': None,
#   '_source': {'account_number': 2,
#    'balance': 28838,
#    'firstname': 'Roberta',
#    'lastname': 'Bender',
#    'age': 22,
#    'gender': 'F',
#    'address': '560 Kingsway Place',
#    'employer': 'Chillium',
#    'email': 'robertabender@chillium.com',
#    'city': 'Bennett',
#    'state': 'LA'},
#   'sort': [2]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'knRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 2,
#    'balance': 28838,
#    'firstname': 'Roberta',
#    'lastname': 'Bender',
#    'age': 22,
#    'gender': 'F',
#    'address': '560 Kingsway Place',
#    'employer': 'Chillium',
#    'email': 'robertabender@chillium.com',
#    'city': 'Bennett',
#    'state': 'LA'},
#   'sort': [2]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'YnRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 2,
#    'balance': 28838,
#    'firstname': 'Roberta',
#    'lastname': 'Bender',
#    'age': 22,
#    'gender': 'F',
#    'address': '560 Kingsway Place',
#    'employer': 'Chillium',
#    'email': 'robertabender@chillium.com',
#    'city': 'Bennett',
#    'state': 'LA'},
#   'sort': [2]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'MnRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 2,
#    'balance': 28838,
#    'firstname': 'Roberta',
#    'lastname': 'Bender',
#    'age': 22,
#    'gender': 'F',
#    'address': '560 Kingsway Place',
#    'employer': 'Chillium',
#    'email': 'robertabender@chillium.com',
#    'city': 'Bennett',
#    'state': 'LA'},
#   'sort': [2]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'cXRYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'QnRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'EnRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '4nRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'UXNYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'InRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '8nRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'wnRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '43RYanQBXWwj1NjsoQA7',
#   '_score': None,
#   '_source': {'account_number': 5,
#    'balance': 29342,
#    'firstname': 'Leola',
#    'lastname': 'Stewart',
#    'age': 30,
#    'gender': 'F',
#    'address': '311 Elm Place',
#    'employer': 'Diginetic',
#    'email': 'leolastewart@diginetic.com',
#    'city': 'Fairview',
#    'state': 'NJ'},
#   'sort': [5]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'tHRaanQBXWwj1Njsbwhf',
#   '_score': None,
#   '_source': {'account_number': 5,
#    'balance': 29342,
#    'firstname': 'Leola',
#    'lastname': 'Stewart',
#    'age': 30,
#    'gender': 'F',
#    'address': '311 Elm Place',
#    'employer': 'Diginetic',
#    'email': 'leolastewart@diginetic.com',
#    'city': 'Fairview',
#    'state': 'NJ'},
#   'sort': [5]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'hHRfanQBXWwj1Njs_hCW',
#   '_score': None,
#   '_source': {'account_number': 5,
#    'balance': 29342,
#    'firstname': 'Leola',
#    'lastname': 'Stewart',
#    'age': 30,
#    'gender': 'F',
#    'address': '311 Elm Place',
#    'employer': 'Diginetic',
#    'email': 'leolastewart@diginetic.com',
#    'city': 'Fairview',
#    'state': 'NJ'},
#   'sort': [5]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'VHRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 5,
#    'balance': 29342,
#    'firstname': 'Leola',
#    'lastname': 'Stewart',
#    'age': 30,
#    'gender': 'F',
#    'address': '311 Elm Place',
#    'employer': 'Diginetic',
#    'email': 'leolastewart@diginetic.com',
#    'city': 'Fairview',
#    'state': 'NJ'},
#   'sort': [5]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'M3NYanQBXWwj1Njsnvzq',
#   '_score': None,
#   '_source': {'account_number': 6,
#    'balance': 5686,
#    'firstname': 'Hattie',
#    'lastname': 'Bond',
#    'age': 36,
#    'gender': 'M',
#    'address': '671 Bristol Street',
#    'employer': 'Netagy',
#    'email': 'hattiebond@netagy.com',
#    'city': 'Dante',
#    'state': 'TN'},
#   'sort': [6]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'BHRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 6,
#    'balance': 5686,
#    'firstname': 'Hattie',
#    'lastname': 'Bond',
#    'age': 36,
#    'gender': 'M',
#    'address': '671 Bristol Street',
#    'employer': 'Netagy',
#    'email': 'hattiebond@netagy.com',
#    'city': 'Dante',
#    'state': 'TN'},
#   'sort': [6]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '1HRfanQBXWwj1Njs_QvY',
#   '_score': None,
#   '_source': {'account_number': 6,
#    'balance': 5686,
#    'firstname': 'Hattie',
#    'lastname': 'Bond',
#    'age': 36,
#    'gender': 'M',
#    'address': '671 Bristol Street',
#    'employer': 'Netagy',
#    'email': 'hattiebond@netagy.com',
#    'city': 'Dante',
#    'state': 'TN'},
#   'sort': [6]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'pHRganQBXWwj1NjsHhP4',
#   '_score': None,
#   '_source': {'account_number': 6,
#    'balance': 5686,
#    'firstname': 'Hattie',
#    'lastname': 'Bond',
#    'age': 36,
#    'gender': 'M',
#    'address': '671 Bristol Street',
#    'employer': 'Netagy',
#    'email': 'hattiebond@netagy.com',
#    'city': 'Dante',
#    'state': 'TN'},
#   'sort': [6]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'w3NYanQBXWwj1Njsnv3t',
#   '_score': None,
#   '_source': {'account_number': 7,
#    'balance': 39121,
#    'firstname': 'Levy',
#    'lastname': 'Richard',
#    'age': 22,
#    'gender': 'M',
#    'address': '820 Logan Street',
#    'employer': 'Teraprene',
#    'email': 'levyrichard@teraprene.com',
#    'city': 'Shrewsbury',
#    'state': 'MO'},
#   'sort': [7]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'lHRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 7,
#    'balance': 39121,
#    'firstname': 'Levy',
#    'lastname': 'Richard',
#    'age': 22,
#    'gender': 'M',
#    'address': '820 Logan Street',
#    'employer': 'Teraprene',
#    'email': 'levyrichard@teraprene.com',
#    'city': 'Shrewsbury',
#    'state': 'MO'},
#   'sort': [7]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'ZHRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 7,
#    'balance': 39121,
#    'firstname': 'Levy',
#    'lastname': 'Richard',
#    'age': 22,
#    'gender': 'M',
#    'address': '820 Logan Street',
#    'employer': 'Teraprene',
#    'email': 'levyrichard@teraprene.com',
#    'city': 'Shrewsbury',
#    'state': 'MO'},
#   'sort': [7]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'NHRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 7,
#    'balance': 39121,
#    'firstname': 'Levy',
#    'lastname': 'Richard',
#    'age': 22,
#    'gender': 'M',
#    'address': '820 Logan Street',
#    'employer': 'Teraprene',
#    'email': 'levyrichard@teraprene.com',
#    'city': 'Shrewsbury',
#    'state': 'MO'},
#   'sort': [7]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'c3RYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 8,
#    'balance': 48868,
#    'firstname': 'Jan',
#    'lastname': 'Burns',
#    'age': 35,
#    'gender': 'M',
#    'address': '699 Visitation Place',
#    'employer': 'Glasstep',
#    'email': 'janburns@glasstep.com',
#    'city': 'Wakulla',
#    'state': 'AZ'},
#   'sort': [8]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'RHRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 8,
#    'balance': 48868,
#    'firstname': 'Jan',
#    'lastname': 'Burns',
#    'age': 35,
#    'gender': 'M',
#    'address': '699 Visitation Place',
#    'employer': 'Glasstep',
#    'email': 'janburns@glasstep.com',
#    'city': 'Wakulla',
#    'state': 'AZ'},
#   'sort': [8]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'FHRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 8,
#    'balance': 48868,
#    'firstname': 'Jan',
#    'lastname': 'Burns',
#    'age': 35,
#    'gender': 'M',
#    'address': '699 Visitation Place',
#    'employer': 'Glasstep',
#    'email': 'janburns@glasstep.com',
#    'city': 'Wakulla',
#    'state': 'AZ'},
#   'sort': [8]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '5HRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 8,
#    'balance': 48868,
#    'firstname': 'Jan',
#    'lastname': 'Burns',
#    'age': 35,
#    'gender': 'M',
#    'address': '699 Visitation Place',
#    'employer': 'Glasstep',
#    'email': 'janburns@glasstep.com',
#    'city': 'Wakulla',
#    'state': 'AZ'},
#   'sort': [8]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'U3NYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 9,
#    'balance': 24776,
#    'firstname': 'Opal',
#    'lastname': 'Meadows',
#    'age': 39,
#    'gender': 'M',
#    'address': '963 Neptune Avenue',
#    'employer': 'Cedward',
#    'email': 'opalmeadows@cedward.com',
#    'city': 'Olney',
#    'state': 'OH'},
#   'sort': [9]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'JHRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 9,
#    'balance': 24776,
#    'firstname': 'Opal',
#    'lastname': 'Meadows',
#    'age': 39,
#    'gender': 'M',
#    'address': '963 Neptune Avenue',
#    'employer': 'Cedward',
#    'email': 'opalmeadows@cedward.com',
#    'city': 'Olney',
#    'state': 'OH'},
#   'sort': [9]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '9HRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 9,
#    'balance': 24776,
#    'firstname': 'Opal',
#    'lastname': 'Meadows',
#    'age': 39,
#    'gender': 'M',
#    'address': '963 Neptune Avenue',
#    'employer': 'Cedward',
#    'email': 'opalmeadows@cedward.com',
#    'city': 'Olney',
#    'state': 'OH'},
#   'sort': [9]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'xHRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 9,
#    'balance': 24776,
#    'firstname': 'Opal',
#    'lastname': 'Meadows',
#    'age': 39,
#    'gender': 'M',
#    'address': '963 Neptune Avenue',
#    'employer': 'Cedward',
#    'email': 'opalmeadows@cedward.com',
#    'city': 'Olney',
#    'state': 'OH'},
#   'sort': [9]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'dXRYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 10,
#    'balance': 46170,
#    'firstname': 'Dominique',
#    'lastname': 'Park',
#    'age': 37,
#    'gender': 'F',
#    'address': '100 Gatling Place',
#    'employer': 'Conjurica',
#    'email': 'dominiquepark@conjurica.com',
#    'city': 'Omar',
#    'state': 'NJ'},
#   'sort': [10]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'RnRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 10,
#    'balance': 46170,
#    'firstname': 'Dominique',
#    'lastname': 'Park',
#    'age': 37,
#    'gender': 'F',
#    'address': '100 Gatling Place',
#    'employer': 'Conjurica',
#    'email': 'dominiquepark@conjurica.com',
#    'city': 'Omar',
#    'state': 'NJ'},
#   'sort': [10]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'FnRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 10,
#    'balance': 46170,
#    'firstname': 'Dominique',
#    'lastname': 'Park',
#    'age': 37,
#    'gender': 'F',
#    'address': '100 Gatling Place',
#    'employer': 'Conjurica',
#    'email': 'dominiquepark@conjurica.com',
#    'city': 'Omar',
#    'state': 'NJ'},
#   'sort': [10]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '5nRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 10,
#    'balance': 46170,
#    'firstname': 'Dominique',
#    'lastname': 'Park',
#    'age': 37,
#    'gender': 'F',
#    'address': '100 Gatling Place',
#    'employer': 'Conjurica',
#    'email': 'dominiquepark@conjurica.com',
#    'city': 'Omar',
#    'state': 'NJ'},
#   'sort': [10]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'VXNYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 11,
#    'balance': 20203,
#    'firstname': 'Jenkins',
#    'lastname': 'Haney',
#    'age': 20,
#    'gender': 'M',
#    'address': '740 Ferry Place',
#    'employer': 'Qimonk',
#    'email': 'jenkinshaney@qimonk.com',
#    'city': 'Steinhatchee',
#    'state': 'GA'},
#   'sort': [11]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'JnRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 11,
#    'balance': 20203,
#    'firstname': 'Jenkins',
#    'lastname': 'Haney',
#    'age': 20,
#    'gender': 'M',
#    'address': '740 Ferry Place',
#    'employer': 'Qimonk',
#    'email': 'jenkinshaney@qimonk.com',
#    'city': 'Steinhatchee',
#    'state': 'GA'},
#   'sort': [11]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '9nRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 11,
#    'balance': 20203,
#    'firstname': 'Jenkins',
#    'lastname': 'Haney',
#    'age': 20,
#    'gender': 'M',
#    'address': '740 Ferry Place',
#    'employer': 'Qimonk',
#    'email': 'jenkinshaney@qimonk.com',
#    'city': 'Steinhatchee',
#    'state': 'GA'},
#   'sort': [11]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'xnRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 11,
#    'balance': 20203,
#    'firstname': 'Jenkins',
#    'lastname': 'Haney',
#    'age': 20,
#    'gender': 'M',
#    'address': '740 Ferry Place',
#    'employer': 'Qimonk',
#    'email': 'jenkinshaney@qimonk.com',
#    'city': 'Steinhatchee',
#    'state': 'GA'},
#   'sort': [11]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '5XRYanQBXWwj1NjsoQA7',
#   '_score': None,
#   '_source': {'account_number': 12,
#    'balance': 37055,
#    'firstname': 'Stafford',
#    'lastname': 'Brock',
#    'age': 20,
#    'gender': 'F',
#    'address': '296 Wythe Avenue',
#    'employer': 'Uncorp',
#    'email': 'staffordbrock@uncorp.com',
#    'city': 'Bend',
#    'state': 'AL'},
#   'sort': [12]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'tnRaanQBXWwj1Njsbwhf',
#   '_score': None,
#   '_source': {'account_number': 12,
#    'balance': 37055,
#    'firstname': 'Stafford',
#    'lastname': 'Brock',
#    'age': 20,
#    'gender': 'F',
#    'address': '296 Wythe Avenue',
#    'employer': 'Uncorp',
#    'email': 'staffordbrock@uncorp.com',
#    'city': 'Bend',
#    'state': 'AL'},
#   'sort': [12]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'hnRfanQBXWwj1Njs_hCW',
#   '_score': None,
#   '_source': {'account_number': 12,
#    'balance': 37055,
#    'firstname': 'Stafford',
#    'lastname': 'Brock',
#    'age': 20,
#    'gender': 'F',
#    'address': '296 Wythe Avenue',
#    'employer': 'Uncorp',
#    'email': 'staffordbrock@uncorp.com',
#    'city': 'Bend',
#    'state': 'AL'},
#   'sort': [12]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'VnRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 12,
#    'balance': 37055,
#    'firstname': 'Stafford',
#    'lastname': 'Brock',
#    'age': 20,
#    'gender': 'F',
#    'address': '296 Wythe Avenue',
#    'employer': 'Uncorp',
#    'email': 'staffordbrock@uncorp.com',
#    'city': 'Bend',
#    'state': 'AL'},
#   'sort': [12]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'NXNYanQBXWwj1Njsnvzq',
#   '_score': None,
#   '_source': {'account_number': 13,
#    'balance': 32838,
#    'firstname': 'Nanette',
#    'lastname': 'Bates',
#    'age': 28,
#    'gender': 'F',
#    'address': '789 Madison Street',
#    'employer': 'Quility',
#    'email': 'nanettebates@quility.com',
#    'city': 'Nogal',
#    'state': 'VA'},
#   'sort': [13]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'BnRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 13,
#    'balance': 32838,
#    'firstname': 'Nanette',
#    'lastname': 'Bates',
#    'age': 28,
#    'gender': 'F',
#    'address': '789 Madison Street',
#    'employer': 'Quility',
#    'email': 'nanettebates@quility.com',
#    'city': 'Nogal',
#    'state': 'VA'},
#   'sort': [13]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '1nRfanQBXWwj1Njs_QvY',
#   '_score': None,
#   '_source': {'account_number': 13,
#    'balance': 32838,
#    'firstname': 'Nanette',
#    'lastname': 'Bates',
#    'age': 28,
#    'gender': 'F',
#    'address': '789 Madison Street',
#    'employer': 'Quility',
#    'email': 'nanettebates@quility.com',
#    'city': 'Nogal',
#    'state': 'VA'},
#   'sort': [13]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'pnRganQBXWwj1NjsHhP4',
#   '_score': None,
#   '_source': {'account_number': 13,
#    'balance': 32838,
#    'firstname': 'Nanette',
#    'lastname': 'Bates',
#    'age': 28,
#    'gender': 'F',
#    'address': '789 Madison Street',
#    'employer': 'Quility',
#    'email': 'nanettebates@quility.com',
#    'city': 'Nogal',
#    'state': 'VA'},
#   'sort': [13]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'xXNYanQBXWwj1Njsnv3t',
#   '_score': None,
#   '_source': {'account_number': 14,
#    'balance': 20480,
#    'firstname': 'Erma',
#    'lastname': 'Kane',
#    'age': 39,
#    'gender': 'F',
#    'address': '661 Vista Place',
#    'employer': 'Stockpost',
#    'email': 'ermakane@stockpost.com',
#    'city': 'Chamizal',
#    'state': 'NY'},
#   'sort': [14]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'lnRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 14,
#    'balance': 20480,
#    'firstname': 'Erma',
#    'lastname': 'Kane',
#    'age': 39,
#    'gender': 'F',
#    'address': '661 Vista Place',
#    'employer': 'Stockpost',
#    'email': 'ermakane@stockpost.com',
#    'city': 'Chamizal',
#    'state': 'NY'},
#   'sort': [14]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'ZnRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 14,
#    'balance': 20480,
#    'firstname': 'Erma',
#    'lastname': 'Kane',
#    'age': 39,
#    'gender': 'F',
#    'address': '661 Vista Place',
#    'employer': 'Stockpost',
#    'email': 'ermakane@stockpost.com',
#    'city': 'Chamizal',
#    'state': 'NY'},
#   'sort': [14]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'NnRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 14,
#    'balance': 20480,
#    'firstname': 'Erma',
#    'lastname': 'Kane',
#    'age': 39,
#    'gender': 'F',
#    'address': '661 Vista Place',
#    'employer': 'Stockpost',
#    'email': 'ermakane@stockpost.com',
#    'city': 'Chamizal',
#    'state': 'NY'},
#   'sort': [14]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'd3RYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 15,
#    'balance': 43456,
#    'firstname': 'Bobbie',
#    'lastname': 'Sexton',
#    'age': 21,
#    'gender': 'M',
#    'address': '232 Sedgwick Place',
#    'employer': 'Zytrex',
#    'email': 'bobbiesexton@zytrex.com',
#    'city': 'Hendersonville',
#    'state': 'CA'},
#   'sort': [15]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'SHRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 15,
#    'balance': 43456,
#    'firstname': 'Bobbie',
#    'lastname': 'Sexton',
#    'age': 21,
#    'gender': 'M',
#    'address': '232 Sedgwick Place',
#    'employer': 'Zytrex',
#    'email': 'bobbiesexton@zytrex.com',
#    'city': 'Hendersonville',
#    'state': 'CA'},
#   'sort': [15]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'GHRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 15,
#    'balance': 43456,
#    'firstname': 'Bobbie',
#    'lastname': 'Sexton',
#    'age': 21,
#    'gender': 'M',
#    'address': '232 Sedgwick Place',
#    'employer': 'Zytrex',
#    'email': 'bobbiesexton@zytrex.com',
#    'city': 'Hendersonville',
#    'state': 'CA'},
#   'sort': [15]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '6HRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 15,
#    'balance': 43456,
#    'firstname': 'Bobbie',
#    'lastname': 'Sexton',
#    'age': 21,
#    'gender': 'M',
#    'address': '232 Sedgwick Place',
#    'employer': 'Zytrex',
#    'email': 'bobbiesexton@zytrex.com',
#    'city': 'Hendersonville',
#    'state': 'CA'},
#   'sort': [15]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'V3NYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 16,
#    'balance': 35883,
#    'firstname': 'Adrian',
#    'lastname': 'Pitts',
#    'age': 34,
#    'gender': 'F',
#    'address': '963 Fay Court',
#    'employer': 'Combogene',
#    'email': 'adrianpitts@combogene.com',
#    'city': 'Remington',
#    'state': 'SD'},
#   'sort': [16]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'KHRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 16,
#    'balance': 35883,
#    'firstname': 'Adrian',
#    'lastname': 'Pitts',
#    'age': 34,
#    'gender': 'F',
#    'address': '963 Fay Court',
#    'employer': 'Combogene',
#    'email': 'adrianpitts@combogene.com',
#    'city': 'Remington',
#    'state': 'SD'},
#   'sort': [16]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '-HRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 16,
#    'balance': 35883,
#    'firstname': 'Adrian',
#    'lastname': 'Pitts',
#    'age': 34,
#    'gender': 'F',
#    'address': '963 Fay Court',
#    'employer': 'Combogene',
#    'email': 'adrianpitts@combogene.com',
#    'city': 'Remington',
#    'state': 'SD'},
#   'sort': [16]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'yHRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 16,
#    'balance': 35883,
#    'firstname': 'Adrian',
#    'lastname': 'Pitts',
#    'age': 34,
#    'gender': 'F',
#    'address': '963 Fay Court',
#    'employer': 'Combogene',
#    'email': 'adrianpitts@combogene.com',
#    'city': 'Remington',
#    'state': 'SD'},
#   'sort': [16]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '53RYanQBXWwj1NjsoQA7',
#   '_score': None,
#   '_source': {'account_number': 17,
#    'balance': 7831,
#    'firstname': 'Bessie',
#    'lastname': 'Orr',
#    'age': 31,
#    'gender': 'F',
#    'address': '239 Hinsdale Street',
#    'employer': 'Skyplex',
#    'email': 'bessieorr@skyplex.com',
#    'city': 'Graball',
#    'state': 'FL'},
#   'sort': [17]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'uHRaanQBXWwj1Njsbwhf',
#   '_score': None,
#   '_source': {'account_number': 17,
#    'balance': 7831,
#    'firstname': 'Bessie',
#    'lastname': 'Orr',
#    'age': 31,
#    'gender': 'F',
#    'address': '239 Hinsdale Street',
#    'employer': 'Skyplex',
#    'email': 'bessieorr@skyplex.com',
#    'city': 'Graball',
#    'state': 'FL'},
#   'sort': [17]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'iHRfanQBXWwj1Njs_hCW',
#   '_score': None,
#   '_source': {'account_number': 17,
#    'balance': 7831,
#    'firstname': 'Bessie',
#    'lastname': 'Orr',
#    'age': 31,
#    'gender': 'F',
#    'address': '239 Hinsdale Street',
#    'employer': 'Skyplex',
#    'email': 'bessieorr@skyplex.com',
#    'city': 'Graball',
#    'state': 'FL'},
#   'sort': [17]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'WHRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 17,
#    'balance': 7831,
#    'firstname': 'Bessie',
#    'lastname': 'Orr',
#    'age': 31,
#    'gender': 'F',
#    'address': '239 Hinsdale Street',
#    'employer': 'Skyplex',
#    'email': 'bessieorr@skyplex.com',
#    'city': 'Graball',
#    'state': 'FL'},
#   'sort': [17]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'N3NYanQBXWwj1Njsnvzq',
#   '_score': None,
#   '_source': {'account_number': 18,
#    'balance': 4180,
#    'firstname': 'Dale',
#    'lastname': 'Adams',
#    'age': 33,
#    'gender': 'M',
#    'address': '467 Hutchinson Court',
#    'employer': 'Boink',
#    'email': 'daleadams@boink.com',
#    'city': 'Orick',
#    'state': 'MD'},
#   'sort': [18]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'CHRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 18,
#    'balance': 4180,
#    'firstname': 'Dale',
#    'lastname': 'Adams',
#    'age': 33,
#    'gender': 'M',
#    'address': '467 Hutchinson Court',
#    'employer': 'Boink',
#    'email': 'daleadams@boink.com',
#    'city': 'Orick',
#    'state': 'MD'},
#   'sort': [18]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '2HRfanQBXWwj1Njs_QvY',
#   '_score': None,
#   '_source': {'account_number': 18,
#    'balance': 4180,
#    'firstname': 'Dale',
#    'lastname': 'Adams',
#    'age': 33,
#    'gender': 'M',
#    'address': '467 Hutchinson Court',
#    'employer': 'Boink',
#    'email': 'daleadams@boink.com',
#    'city': 'Orick',
#    'state': 'MD'},
#   'sort': [18]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'qHRganQBXWwj1NjsHhP4',
#   '_score': None,
#   '_source': {'account_number': 18,
#    'balance': 4180,
#    'firstname': 'Dale',
#    'lastname': 'Adams',
#    'age': 33,
#    'gender': 'M',
#    'address': '467 Hutchinson Court',
#    'employer': 'Boink',
#    'email': 'daleadams@boink.com',
#    'city': 'Orick',
#    'state': 'MD'},
#   'sort': [18]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'x3NYanQBXWwj1Njsnv3t',
#   '_score': None,
#   '_source': {'account_number': 19,
#    'balance': 27894,
#    'firstname': 'Schwartz',
#    'lastname': 'Buchanan',
#    'age': 28,
#    'gender': 'F',
#    'address': '449 Mersereau Court',
#    'employer': 'Sybixtex',
#    'email': 'schwartzbuchanan@sybixtex.com',
#    'city': 'Greenwich',
#    'state': 'KS'},
#   'sort': [19]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'mHRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 19,
#    'balance': 27894,
#    'firstname': 'Schwartz',
#    'lastname': 'Buchanan',
#    'age': 28,
#    'gender': 'F',
#    'address': '449 Mersereau Court',
#    'employer': 'Sybixtex',
#    'email': 'schwartzbuchanan@sybixtex.com',
#    'city': 'Greenwich',
#    'state': 'KS'},
#   'sort': [19]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'aHRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 19,
#    'balance': 27894,
#    'firstname': 'Schwartz',
#    'lastname': 'Buchanan',
#    'age': 28,
#    'gender': 'F',
#    'address': '449 Mersereau Court',
#    'employer': 'Sybixtex',
#    'email': 'schwartzbuchanan@sybixtex.com',
#    'city': 'Greenwich',
#    'state': 'KS'},
#   'sort': [19]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'OHRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 19,
#    'balance': 27894,
#    'firstname': 'Schwartz',
#    'lastname': 'Buchanan',
#    'age': 28,
#    'gender': 'F',
#    'address': '449 Mersereau Court',
#    'employer': 'Sybixtex',
#    'email': 'schwartzbuchanan@sybixtex.com',
#    'city': 'Greenwich',
#    'state': 'KS'},
#   'sort': [19]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'OXNYanQBXWwj1Njsnvzq',
#   '_score': None,
#   '_source': {'account_number': 20,
#    'balance': 16418,
#    'firstname': 'Elinor',
#    'lastname': 'Ratliff',
#    'age': 36,
#    'gender': 'M',
#    'address': '282 Kings Place',
#    'employer': 'Scentric',
#    'email': 'elinorratliff@scentric.com',
#    'city': 'Ribera',
#    'state': 'WA'},
#   'sort': [20]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'CnRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 20,
#    'balance': 16418,
#    'firstname': 'Elinor',
#    'lastname': 'Ratliff',
#    'age': 36,
#    'gender': 'M',
#    'address': '282 Kings Place',
#    'employer': 'Scentric',
#    'email': 'elinorratliff@scentric.com',
#    'city': 'Ribera',
#    'state': 'WA'},
#   'sort': [20]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '2nRfanQBXWwj1Njs_QvY',
#   '_score': None,
#   '_source': {'account_number': 20,
#    'balance': 16418,
#    'firstname': 'Elinor',
#    'lastname': 'Ratliff',
#    'age': 36,
#    'gender': 'M',
#    'address': '282 Kings Place',
#    'employer': 'Scentric',
#    'email': 'elinorratliff@scentric.com',
#    'city': 'Ribera',
#    'state': 'WA'},
#   'sort': [20]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'qnRganQBXWwj1NjsHhP4',
#   '_score': None,
#   '_source': {'account_number': 20,
#    'balance': 16418,
#    'firstname': 'Elinor',
#    'lastname': 'Ratliff',
#    'age': 36,
#    'gender': 'M',
#    'address': '282 Kings Place',
#    'employer': 'Scentric',
#    'email': 'elinorratliff@scentric.com',
#    'city': 'Ribera',
#    'state': 'WA'},
#   'sort': [20]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'yXNYanQBXWwj1Njsnv3t',
#   '_score': None,
#   '_source': {'account_number': 21,
#    'balance': 7004,
#    'firstname': 'Estella',
#    'lastname': 'Paul',
#    'age': 38,
#    'gender': 'M',
#    'address': '859 Portal Street',
#    'employer': 'Zillatide',
#    'email': 'estellapaul@zillatide.com',
#    'city': 'Churchill',
#    'state': 'WV'},
#   'sort': [21]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'mnRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 21,
#    'balance': 7004,
#    'firstname': 'Estella',
#    'lastname': 'Paul',
#    'age': 38,
#    'gender': 'M',
#    'address': '859 Portal Street',
#    'employer': 'Zillatide',
#    'email': 'estellapaul@zillatide.com',
#    'city': 'Churchill',
#    'state': 'WV'},
#   'sort': [21]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'anRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 21,
#    'balance': 7004,
#    'firstname': 'Estella',
#    'lastname': 'Paul',
#    'age': 38,
#    'gender': 'M',
#    'address': '859 Portal Street',
#    'employer': 'Zillatide',
#    'email': 'estellapaul@zillatide.com',
#    'city': 'Churchill',
#    'state': 'WV'},
#   'sort': [21]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'OnRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 21,
#    'balance': 7004,
#    'firstname': 'Estella',
#    'lastname': 'Paul',
#    'age': 38,
#    'gender': 'M',
#    'address': '859 Portal Street',
#    'employer': 'Zillatide',
#    'email': 'estellapaul@zillatide.com',
#    'city': 'Churchill',
#    'state': 'WV'},
#   'sort': [21]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'eXRYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 22,
#    'balance': 40283,
#    'firstname': 'Barrera',
#    'lastname': 'Terrell',
#    'age': 23,
#    'gender': 'F',
#    'address': '292 Orange Street',
#    'employer': 'Steelfab',
#    'email': 'barreraterrell@steelfab.com',
#    'city': 'Bynum',
#    'state': 'ME'},
#   'sort': [22]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'SnRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 22,
#    'balance': 40283,
#    'firstname': 'Barrera',
#    'lastname': 'Terrell',
#    'age': 23,
#    'gender': 'F',
#    'address': '292 Orange Street',
#    'employer': 'Steelfab',
#    'email': 'barreraterrell@steelfab.com',
#    'city': 'Bynum',
#    'state': 'ME'},
#   'sort': [22]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'GnRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 22,
#    'balance': 40283,
#    'firstname': 'Barrera',
#    'lastname': 'Terrell',
#    'age': 23,
#    'gender': 'F',
#    'address': '292 Orange Street',
#    'employer': 'Steelfab',
#    'email': 'barreraterrell@steelfab.com',
#    'city': 'Bynum',
#    'state': 'ME'},
#   'sort': [22]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '6nRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 22,
#    'balance': 40283,
#    'firstname': 'Barrera',
#    'lastname': 'Terrell',
#    'age': 23,
#    'gender': 'F',
#    'address': '292 Orange Street',
#    'employer': 'Steelfab',
#    'email': 'barreraterrell@steelfab.com',
#    'city': 'Bynum',
#    'state': 'ME'},
#   'sort': [22]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'WXNYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 23,
#    'balance': 42374,
#    'firstname': 'Kirsten',
#    'lastname': 'Fox',
#    'age': 20,
#    'gender': 'M',
#    'address': '330 Dumont Avenue',
#    'employer': 'Codax',
#    'email': 'kirstenfox@codax.com',
#    'city': 'Walton',
#    'state': 'AK'},
#   'sort': [23]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'KnRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 23,
#    'balance': 42374,
#    'firstname': 'Kirsten',
#    'lastname': 'Fox',
#    'age': 20,
#    'gender': 'M',
#    'address': '330 Dumont Avenue',
#    'employer': 'Codax',
#    'email': 'kirstenfox@codax.com',
#    'city': 'Walton',
#    'state': 'AK'},
#   'sort': [23]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '-nRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 23,
#    'balance': 42374,
#    'firstname': 'Kirsten',
#    'lastname': 'Fox',
#    'age': 20,
#    'gender': 'M',
#    'address': '330 Dumont Avenue',
#    'employer': 'Codax',
#    'email': 'kirstenfox@codax.com',
#    'city': 'Walton',
#    'state': 'AK'},
#   'sort': [23]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'ynRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 23,
#    'balance': 42374,
#    'firstname': 'Kirsten',
#    'lastname': 'Fox',
#    'age': 20,
#    'gender': 'M',
#    'address': '330 Dumont Avenue',
#    'employer': 'Codax',
#    'email': 'kirstenfox@codax.com',
#    'city': 'Walton',
#    'state': 'AK'},
#   'sort': [23]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '6XRYanQBXWwj1NjsoQA7',
#   '_score': None,
#   '_source': {'account_number': 24,
#    'balance': 44182,
#    'firstname': 'Wood',
#    'lastname': 'Dale',
#    'age': 39,
#    'gender': 'M',
#    'address': '582 Gelston Avenue',
#    'employer': 'Besto',
#    'email': 'wooddale@besto.com',
#    'city': 'Juntura',
#    'state': 'MI'},
#   'sort': [24]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'unRaanQBXWwj1Njsbwhf',
#   '_score': None,
#   '_source': {'account_number': 24,
#    'balance': 44182,
#    'firstname': 'Wood',
#    'lastname': 'Dale',
#    'age': 39,
#    'gender': 'M',
#    'address': '582 Gelston Avenue',
#    'employer': 'Besto',
#    'email': 'wooddale@besto.com',
#    'city': 'Juntura',
#    'state': 'MI'},
#   'sort': [24]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'inRfanQBXWwj1Njs_hCW',
#   '_score': None,
#   '_source': {'account_number': 24,
#    'balance': 44182,
#    'firstname': 'Wood',
#    'lastname': 'Dale',
#    'age': 39,
#    'gender': 'M',
#    'address': '582 Gelston Avenue',
#    'employer': 'Besto',
#    'email': 'wooddale@besto.com',
#    'city': 'Juntura',
#    'state': 'MI'},
#   'sort': [24]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'WnRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 24,
#    'balance': 44182,
#    'firstname': 'Wood',
#    'lastname': 'Dale',
#    'age': 39,
#    'gender': 'M',
#    'address': '582 Gelston Avenue',
#    'employer': 'Besto',
#    'email': 'wooddale@besto.com',
#    'city': 'Juntura',
#    'state': 'MI'},
#   'sort': [24]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'O3NYanQBXWwj1Njsnvzq',
#   '_score': None,
#   '_source': {'account_number': 25,
#    'balance': 40540,
#    'firstname': 'Virginia',
#    'lastname': 'Ayala',
#    'age': 39,
#    'gender': 'F',
#    'address': '171 Putnam Avenue',
#    'employer': 'Filodyne',
#    'email': 'virginiaayala@filodyne.com',
#    'city': 'Nicholson',
#    'state': 'PA'},
#   'sort': [25]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'DHRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 25,
#    'balance': 40540,
#    'firstname': 'Virginia',
#    'lastname': 'Ayala',
#    'age': 39,
#    'gender': 'F',
#    'address': '171 Putnam Avenue',
#    'employer': 'Filodyne',
#    'email': 'virginiaayala@filodyne.com',
#    'city': 'Nicholson',
#    'state': 'PA'},
#   'sort': [25]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '3HRfanQBXWwj1Njs_QvY',
#   '_score': None,
#   '_source': {'account_number': 25,
#    'balance': 40540,
#    'firstname': 'Virginia',
#    'lastname': 'Ayala',
#    'age': 39,
#    'gender': 'F',
#    'address': '171 Putnam Avenue',
#    'employer': 'Filodyne',
#    'email': 'virginiaayala@filodyne.com',
#    'city': 'Nicholson',
#    'state': 'PA'},
#   'sort': [25]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'rHRganQBXWwj1NjsHhP4',
#   '_score': None,
#   '_source': {'account_number': 25,
#    'balance': 40540,
#    'firstname': 'Virginia',
#    'lastname': 'Ayala',
#    'age': 39,
#    'gender': 'F',
#    'address': '171 Putnam Avenue',
#    'employer': 'Filodyne',
#    'email': 'virginiaayala@filodyne.com',
#    'city': 'Nicholson',
#    'state': 'PA'},
#   'sort': [25]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'y3NYanQBXWwj1Njsnv3t',
#   '_score': None,
#   '_source': {'account_number': 26,
#    'balance': 14127,
#    'firstname': 'Lorraine',
#    'lastname': 'Mccullough',
#    'age': 39,
#    'gender': 'F',
#    'address': '157 Dupont Street',
#    'employer': 'Zosis',
#    'email': 'lorrainemccullough@zosis.com',
#    'city': 'Dennard',
#    'state': 'NH'},
#   'sort': [26]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'nHRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 26,
#    'balance': 14127,
#    'firstname': 'Lorraine',
#    'lastname': 'Mccullough',
#    'age': 39,
#    'gender': 'F',
#    'address': '157 Dupont Street',
#    'employer': 'Zosis',
#    'email': 'lorrainemccullough@zosis.com',
#    'city': 'Dennard',
#    'state': 'NH'},
#   'sort': [26]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'bHRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 26,
#    'balance': 14127,
#    'firstname': 'Lorraine',
#    'lastname': 'Mccullough',
#    'age': 39,
#    'gender': 'F',
#    'address': '157 Dupont Street',
#    'employer': 'Zosis',
#    'email': 'lorrainemccullough@zosis.com',
#    'city': 'Dennard',
#    'state': 'NH'},
#   'sort': [26]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'PHRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 26,
#    'balance': 14127,
#    'firstname': 'Lorraine',
#    'lastname': 'Mccullough',
#    'age': 39,
#    'gender': 'F',
#    'address': '157 Dupont Street',
#    'employer': 'Zosis',
#    'email': 'lorrainemccullough@zosis.com',
#    'city': 'Dennard',
#    'state': 'NH'},
#   'sort': [26]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'e3RYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 27,
#    'balance': 6176,
#    'firstname': 'Meyers',
#    'lastname': 'Williamson',
#    'age': 26,
#    'gender': 'F',
#    'address': '675 Henderson Walk',
#    'employer': 'Plexia',
#    'email': 'meyerswilliamson@plexia.com',
#    'city': 'Richmond',
#    'state': 'AZ'},
#   'sort': [27]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'THRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 27,
#    'balance': 6176,
#    'firstname': 'Meyers',
#    'lastname': 'Williamson',
#    'age': 26,
#    'gender': 'F',
#    'address': '675 Henderson Walk',
#    'employer': 'Plexia',
#    'email': 'meyerswilliamson@plexia.com',
#    'city': 'Richmond',
#    'state': 'AZ'},
#   'sort': [27]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'HHRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 27,
#    'balance': 6176,
#    'firstname': 'Meyers',
#    'lastname': 'Williamson',
#    'age': 26,
#    'gender': 'F',
#    'address': '675 Henderson Walk',
#    'employer': 'Plexia',
#    'email': 'meyerswilliamson@plexia.com',
#    'city': 'Richmond',
#    'state': 'AZ'},
#   'sort': [27]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '7HRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 27,
#    'balance': 6176,
#    'firstname': 'Meyers',
#    'lastname': 'Williamson',
#    'age': 26,
#    'gender': 'F',
#    'address': '675 Henderson Walk',
#    'employer': 'Plexia',
#    'email': 'meyerswilliamson@plexia.com',
#    'city': 'Richmond',
#    'state': 'AZ'},
#   'sort': [27]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'W3NYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 28,
#    'balance': 42112,
#    'firstname': 'Vega',
#    'lastname': 'Flynn',
#    'age': 20,
#    'gender': 'M',
#    'address': '647 Hyman Court',
#    'employer': 'Accupharm',
#    'email': 'vegaflynn@accupharm.com',
#    'city': 'Masthope',
#    'state': 'OH'},
#   'sort': [28]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'LHRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 28,
#    'balance': 42112,
#    'firstname': 'Vega',
#    'lastname': 'Flynn',
#    'age': 20,
#    'gender': 'M',
#    'address': '647 Hyman Court',
#    'employer': 'Accupharm',
#    'email': 'vegaflynn@accupharm.com',
#    'city': 'Masthope',
#    'state': 'OH'},
#   'sort': [28]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '_HRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 28,
#    'balance': 42112,
#    'firstname': 'Vega',
#    'lastname': 'Flynn',
#    'age': 20,
#    'gender': 'M',
#    'address': '647 Hyman Court',
#    'employer': 'Accupharm',
#    'email': 'vegaflynn@accupharm.com',
#    'city': 'Masthope',
#    'state': 'OH'},
#   'sort': [28]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'zHRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 28,
#    'balance': 42112,
#    'firstname': 'Vega',
#    'lastname': 'Flynn',
#    'age': 20,
#    'gender': 'M',
#    'address': '647 Hyman Court',
#    'employer': 'Accupharm',
#    'email': 'vegaflynn@accupharm.com',
#    'city': 'Masthope',
#    'state': 'OH'},
#   'sort': [28]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '63RYanQBXWwj1NjsoQA7',
#   '_score': None,
#   '_source': {'account_number': 29,
#    'balance': 27323,
#    'firstname': 'Leah',
#    'lastname': 'Santiago',
#    'age': 33,
#    'gender': 'M',
#    'address': '193 Schenck Avenue',
#    'employer': 'Isologix',
#    'email': 'leahsantiago@isologix.com',
#    'city': 'Gerton',
#    'state': 'ND'},
#   'sort': [29]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'vHRaanQBXWwj1Njsbwhf',
#   '_score': None,
#   '_source': {'account_number': 29,
#    'balance': 27323,
#    'firstname': 'Leah',
#    'lastname': 'Santiago',
#    'age': 33,
#    'gender': 'M',
#    'address': '193 Schenck Avenue',
#    'employer': 'Isologix',
#    'email': 'leahsantiago@isologix.com',
#    'city': 'Gerton',
#    'state': 'ND'},
#   'sort': [29]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'jHRfanQBXWwj1Njs_hCW',
#   '_score': None,
#   '_source': {'account_number': 29,
#    'balance': 27323,
#    'firstname': 'Leah',
#    'lastname': 'Santiago',
#    'age': 33,
#    'gender': 'M',
#    'address': '193 Schenck Avenue',
#    'employer': 'Isologix',
#    'email': 'leahsantiago@isologix.com',
#    'city': 'Gerton',
#    'state': 'ND'},
#   'sort': [29]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'XHRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 29,
#    'balance': 27323,
#    'firstname': 'Leah',
#    'lastname': 'Santiago',
#    'age': 33,
#    'gender': 'M',
#    'address': '193 Schenck Avenue',
#    'employer': 'Isologix',
#    'email': 'leahsantiago@isologix.com',
#    'city': 'Gerton',
#    'state': 'ND'},
#   'sort': [29]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'XXNYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 30,
#    'balance': 19087,
#    'firstname': 'Lamb',
#    'lastname': 'Townsend',
#    'age': 26,
#    'gender': 'M',
#    'address': '169 Lyme Avenue',
#    'employer': 'Geeknet',
#    'email': 'lambtownsend@geeknet.com',
#    'city': 'Epworth',
#    'state': 'AL'},
#   'sort': [30]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'LnRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 30,
#    'balance': 19087,
#    'firstname': 'Lamb',
#    'lastname': 'Townsend',
#    'age': 26,
#    'gender': 'M',
#    'address': '169 Lyme Avenue',
#    'employer': 'Geeknet',
#    'email': 'lambtownsend@geeknet.com',
#    'city': 'Epworth',
#    'state': 'AL'},
#   'sort': [30]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '_nRfanQBXWwj1Njs_g4_',
#   '_score': None,
# ...
#    'city': 'Belgreen',
#    'state': 'NH'},
#   'sort': [239]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'QXRYanQBXWwj1NjsoQE7',
#   '_score': None,
#   '_source': {'account_number': 240,
#    'balance': 49741,
#    'firstname': 'Oconnor',
#    'lastname': 'Clay',
#    'age': 35,
#    'gender': 'F',
#    'address': '659 Highland Boulevard',
#    'employer': 'Franscene',
#    'email': 'oconnorclay@franscene.com',
#    'city': 'Kilbourne',
#    'state': 'NH'},
#   'sort': [240]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'EnRaanQBXWwj1Njsbwlf',
#   '_score': None,
#   '_source': {'account_number': 240,
#    'balance': 49741,
#    'firstname': 'Oconnor',
#    'lastname': 'Clay',
#    'age': 35,
#    'gender': 'F',
#    'address': '659 Highland Boulevard',
#    'employer': 'Franscene',
#    'email': 'oconnorclay@franscene.com',
#    'city': 'Kilbourne',
#    'state': 'NH'},
#   'sort': [240]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '4nRfanQBXWwj1Njs_hCX',
#   '_score': None,
#   '_source': {'account_number': 240,
#    'balance': 49741,
#    'firstname': 'Oconnor',
#    'lastname': 'Clay',
#    'age': 35,
#    'gender': 'F',
#    'address': '659 Highland Boulevard',
#    'employer': 'Franscene',
#    'email': 'oconnorclay@franscene.com',
#    'city': 'Kilbourne',
#    'state': 'NH'},
#   'sort': [240]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'snRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 240,
#    'balance': 49741,
#    'firstname': 'Oconnor',
#    'lastname': 'Clay',
#    'age': 35,
#    'gender': 'F',
#    'address': '659 Highland Boulevard',
#    'employer': 'Franscene',
#    'email': 'oconnorclay@franscene.com',
#    'city': 'Kilbourne',
#    'state': 'NH'},
#   'sort': [240]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'kXNYanQBXWwj1Njsnvzr',
#   '_score': None,
#   '_source': {'account_number': 241,
#    'balance': 25379,
#    'firstname': 'Schroeder',
#    'lastname': 'Harrington',
#    'age': 26,
#    'gender': 'M',
#    'address': '610 Tapscott Avenue',
#    'employer': 'Otherway',
#    'email': 'schroederharrington@otherway.com',
#    'city': 'Ebro',
#    'state': 'TX'},
#   'sort': [241]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'YnRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 241,
#    'balance': 25379,
#    'firstname': 'Schroeder',
#    'lastname': 'Harrington',
#    'age': 26,
#    'gender': 'M',
#    'address': '610 Tapscott Avenue',
#    'employer': 'Otherway',
#    'email': 'schroederharrington@otherway.com',
#    'city': 'Ebro',
#    'state': 'TX'},
#   'sort': [241]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'MnRfanQBXWwj1Njs_QzY',
#   '_score': None,
#   '_source': {'account_number': 241,
#    'balance': 25379,
#    'firstname': 'Schroeder',
#    'lastname': 'Harrington',
#    'age': 26,
#    'gender': 'M',
#    'address': '610 Tapscott Avenue',
#    'employer': 'Otherway',
#    'email': 'schroederharrington@otherway.com',
#    'city': 'Ebro',
#    'state': 'TX'},
#   'sort': [241]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'AnRganQBXWwj1NjsHhT4',
#   '_score': None,
#   '_source': {'account_number': 241,
#    'balance': 25379,
#    'firstname': 'Schroeder',
#    'lastname': 'Harrington',
#    'age': 26,
#    'gender': 'M',
#    'address': '610 Tapscott Avenue',
#    'employer': 'Otherway',
#    'email': 'schroederharrington@otherway.com',
#    'city': 'Ebro',
#    'state': 'TX'},
#   'sort': [241]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'IXNYanQBXWwj1Njsnv7t',
#   '_score': None,
#   '_source': {'account_number': 242,
#    'balance': 42318,
#    'firstname': 'Berger',
#    'lastname': 'Roach',
#    'age': 21,
#    'gender': 'M',
#    'address': '125 Wakeman Place',
#    'employer': 'Ovium',
#    'email': 'bergerroach@ovium.com',
#    'city': 'Hessville',
#    'state': 'WI'},
#   'sort': [242]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '8nRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 242,
#    'balance': 42318,
#    'firstname': 'Berger',
#    'lastname': 'Roach',
#    'age': 21,
#    'gender': 'M',
#    'address': '125 Wakeman Place',
#    'employer': 'Ovium',
#    'email': 'bergerroach@ovium.com',
#    'city': 'Hessville',
#    'state': 'WI'},
#   'sort': [242]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'wnRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 242,
#    'balance': 42318,
#    'firstname': 'Berger',
#    'lastname': 'Roach',
#    'age': 21,
#    'gender': 'M',
#    'address': '125 Wakeman Place',
#    'employer': 'Ovium',
#    'email': 'bergerroach@ovium.com',
#    'city': 'Hessville',
#    'state': 'WI'},
#   'sort': [242]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'knRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 242,
#    'balance': 42318,
#    'firstname': 'Berger',
#    'lastname': 'Roach',
#    'age': 21,
#    'gender': 'M',
#    'address': '125 Wakeman Place',
#    'employer': 'Ovium',
#    'email': 'bergerroach@ovium.com',
#    'city': 'Hessville',
#    'state': 'WI'},
#   'sort': [242]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '0XRYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 243,
#    'balance': 29902,
#    'firstname': 'Evangelina',
#    'lastname': 'Perez',
#    'age': 20,
#    'gender': 'M',
#    'address': '787 Joval Court',
#    'employer': 'Keengen',
#    'email': 'evangelinaperez@keengen.com',
#    'city': 'Mulberry',
#    'state': 'SD'},
#   'sort': [243]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'onRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 243,
#    'balance': 29902,
#    'firstname': 'Evangelina',
#    'lastname': 'Perez',
#    'age': 20,
#    'gender': 'M',
#    'address': '787 Joval Court',
#    'employer': 'Keengen',
#    'email': 'evangelinaperez@keengen.com',
#    'city': 'Mulberry',
#    'state': 'SD'},
#   'sort': [243]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'cnRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 243,
#    'balance': 29902,
#    'firstname': 'Evangelina',
#    'lastname': 'Perez',
#    'age': 20,
#    'gender': 'M',
#    'address': '787 Joval Court',
#    'employer': 'Keengen',
#    'email': 'evangelinaperez@keengen.com',
#    'city': 'Mulberry',
#    'state': 'SD'},
#   'sort': [243]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'QnRganQBXWwj1NjsHxp5',
#   '_score': None,
#   '_source': {'account_number': 243,
#    'balance': 29902,
#    'firstname': 'Evangelina',
#    'lastname': 'Perez',
#    'age': 20,
#    'gender': 'M',
#    'address': '787 Joval Court',
#    'employer': 'Keengen',
#    'email': 'evangelinaperez@keengen.com',
#    'city': 'Mulberry',
#    'state': 'SD'},
#   'sort': [243]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'sXNYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 244,
#    'balance': 8048,
#    'firstname': 'Judith',
#    'lastname': 'Riggs',
#    'age': 27,
#    'gender': 'F',
#    'address': '590 Kosciusko Street',
#    'employer': 'Arctiq',
#    'email': 'judithriggs@arctiq.com',
#    'city': 'Gorham',
#    'state': 'DC'},
#   'sort': [244]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'gnRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 244,
#    'balance': 8048,
#    'firstname': 'Judith',
#    'lastname': 'Riggs',
#    'age': 27,
#    'gender': 'F',
#    'address': '590 Kosciusko Street',
#    'employer': 'Arctiq',
#    'email': 'judithriggs@arctiq.com',
#    'city': 'Gorham',
#    'state': 'DC'},
#   'sort': [244]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'UnRfanQBXWwj1Njs_g8_',
#   '_score': None,
#   '_source': {'account_number': 244,
#    'balance': 8048,
#    'firstname': 'Judith',
#    'lastname': 'Riggs',
#    'age': 27,
#    'gender': 'F',
#    'address': '590 Kosciusko Street',
#    'employer': 'Arctiq',
#    'email': 'judithriggs@arctiq.com',
#    'city': 'Gorham',
#    'state': 'DC'},
#   'sort': [244]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'InRganQBXWwj1NjsHxcp',
#   '_score': None,
#   '_source': {'account_number': 244,
#    'balance': 8048,
#    'firstname': 'Judith',
#    'lastname': 'Riggs',
#    'age': 27,
#    'gender': 'F',
#    'address': '590 Kosciusko Street',
#    'employer': 'Arctiq',
#    'email': 'judithriggs@arctiq.com',
#    'city': 'Gorham',
#    'state': 'DC'},
#   'sort': [244]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'Q3RYanQBXWwj1NjsoQE7',
#   '_score': None,
#   '_source': {'account_number': 245,
#    'balance': 22026,
#    'firstname': 'Fran',
#    'lastname': 'Bolton',
#    'age': 28,
#    'gender': 'F',
#    'address': '147 Jerome Street',
#    'employer': 'Solaren',
#    'email': 'franbolton@solaren.com',
#    'city': 'Nash',
#    'state': 'RI'},
#   'sort': [245]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'FHRaanQBXWwj1Njsbwlf',
#   '_score': None,
#   '_source': {'account_number': 245,
#    'balance': 22026,
#    'firstname': 'Fran',
#    'lastname': 'Bolton',
#    'age': 28,
#    'gender': 'F',
#    'address': '147 Jerome Street',
#    'employer': 'Solaren',
#    'email': 'franbolton@solaren.com',
#    'city': 'Nash',
#    'state': 'RI'},
#   'sort': [245]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '5HRfanQBXWwj1Njs_hCX',
#   '_score': None,
#   '_source': {'account_number': 245,
#    'balance': 22026,
#    'firstname': 'Fran',
#    'lastname': 'Bolton',
#    'age': 28,
#    'gender': 'F',
#    'address': '147 Jerome Street',
#    'employer': 'Solaren',
#    'email': 'franbolton@solaren.com',
#    'city': 'Nash',
#    'state': 'RI'},
#   'sort': [245]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'tHRganQBXWwj1NjsHxhQ',
#   '_score': None,
#   '_source': {'account_number': 245,
#    'balance': 22026,
#    'firstname': 'Fran',
#    'lastname': 'Bolton',
#    'age': 28,
#    'gender': 'F',
#    'address': '147 Jerome Street',
#    'employer': 'Solaren',
#    'email': 'franbolton@solaren.com',
#    'city': 'Nash',
#    'state': 'RI'},
#   'sort': [245]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'k3NYanQBXWwj1Njsnvzr',
#   '_score': None,
#   '_source': {'account_number': 246,
#    'balance': 28405,
#    'firstname': 'Katheryn',
#    'lastname': 'Foster',
#    'age': 21,
#    'gender': 'F',
#    'address': '259 Kane Street',
#    'employer': 'Quantalia',
#    'email': 'katherynfoster@quantalia.com',
#    'city': 'Bath',
#    'state': 'TX'},
#   'sort': [246]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'ZHRaanQBXWwj1NjsbgTE',
#   '_score': None,
#   '_source': {'account_number': 246,
#    'balance': 28405,
#    'firstname': 'Katheryn',
#    'lastname': 'Foster',
#    'age': 21,
#    'gender': 'F',
#    'address': '259 Kane Street',
#    'employer': 'Quantalia',
#    'email': 'katherynfoster@quantalia.com',
#    'city': 'Bath',
#    'state': 'TX'},
#   'sort': [246]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'NHRfanQBXWwj1Njs_QzY',
#   '_score': None,
#   '_source': {'account_number': 246,
#    'balance': 28405,
#    'firstname': 'Katheryn',
#    'lastname': 'Foster',
#    'age': 21,
#    'gender': 'F',
#    'address': '259 Kane Street',
#    'employer': 'Quantalia',
#    'email': 'katherynfoster@quantalia.com',
#    'city': 'Bath',
#    'state': 'TX'},
#   'sort': [246]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'BHRganQBXWwj1NjsHhT4',
#   '_score': None,
#   '_source': {'account_number': 246,
#    'balance': 28405,
#    'firstname': 'Katheryn',
#    'lastname': 'Foster',
#    'age': 21,
#    'gender': 'F',
#    'address': '259 Kane Street',
#    'employer': 'Quantalia',
#    'email': 'katherynfoster@quantalia.com',
#    'city': 'Bath',
#    'state': 'TX'},
#   'sort': [246]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'I3NYanQBXWwj1Njsnv7t',
#   '_score': None,
#   '_source': {'account_number': 247,
#    'balance': 45123,
#    'firstname': 'Mccormick',
#    'lastname': 'Moon',
#    'age': 37,
#    'gender': 'M',
#    'address': '582 Brighton Avenue',
#    'employer': 'Norsup',
#    'email': 'mccormickmoon@norsup.com',
#    'city': 'Forestburg',
#    'state': 'DE'},
#   'sort': [247]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '9HRaanQBXWwj1NjsbgXE',
#   '_score': None,
#   '_source': {'account_number': 247,
#    'balance': 45123,
#    'firstname': 'Mccormick',
#    'lastname': 'Moon',
#    'age': 37,
#    'gender': 'M',
#    'address': '582 Brighton Avenue',
#    'employer': 'Norsup',
#    'email': 'mccormickmoon@norsup.com',
#    'city': 'Forestburg',
#    'state': 'DE'},
#   'sort': [247]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'xHRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 247,
#    'balance': 45123,
#    'firstname': 'Mccormick',
#    'lastname': 'Moon',
#    'age': 37,
#    'gender': 'M',
#    'address': '582 Brighton Avenue',
#    'employer': 'Norsup',
#    'email': 'mccormickmoon@norsup.com',
#    'city': 'Forestburg',
#    'state': 'DE'},
#   'sort': [247]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'lHRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 247,
#    'balance': 45123,
#    'firstname': 'Mccormick',
#    'lastname': 'Moon',
#    'age': 37,
#    'gender': 'M',
#    'address': '582 Brighton Avenue',
#    'employer': 'Norsup',
#    'email': 'mccormickmoon@norsup.com',
#    'city': 'Forestburg',
#    'state': 'DE'},
#   'sort': [247]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '03RYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 248,
#    'balance': 49989,
#    'firstname': 'West',
#    'lastname': 'England',
#    'age': 36,
#    'gender': 'M',
#    'address': '717 Hendrickson Place',
#    'employer': 'Obliq',
#    'email': 'westengland@obliq.com',
#    'city': 'Maury',
#    'state': 'WA'},
#   'sort': [248]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'pHRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 248,
#    'balance': 49989,
#    'firstname': 'West',
#    'lastname': 'England',
#    'age': 36,
#    'gender': 'M',
#    'address': '717 Hendrickson Place',
#    'employer': 'Obliq',
#    'email': 'westengland@obliq.com',
#    'city': 'Maury',
#    'state': 'WA'},
#   'sort': [248]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'dHRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 248,
#    'balance': 49989,
#    'firstname': 'West',
#    'lastname': 'England',
#    'age': 36,
#    'gender': 'M',
#    'address': '717 Hendrickson Place',
#    'employer': 'Obliq',
#    'email': 'westengland@obliq.com',
#    'city': 'Maury',
#    'state': 'WA'},
#   'sort': [248]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'RHRganQBXWwj1NjsHxp5',
#   '_score': None,
#   '_source': {'account_number': 248,
#    'balance': 49989,
#    'firstname': 'West',
#    'lastname': 'England',
#    'age': 36,
#    'gender': 'M',
#    'address': '717 Hendrickson Place',
#    'employer': 'Obliq',
#    'email': 'westengland@obliq.com',
#    'city': 'Maury',
#    'state': 'WA'},
#   'sort': [248]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 's3NYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 249,
#    'balance': 16822,
#    'firstname': 'Mckinney',
#    'lastname': 'Gallagher',
#    'age': 38,
#    'gender': 'F',
#    'address': '939 Seigel Court',
#    'employer': 'Premiant',
#    'email': 'mckinneygallagher@premiant.com',
#    'city': 'Catharine',
#    'state': 'NH'},
#   'sort': [249]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'hHRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 249,
#    'balance': 16822,
#    'firstname': 'Mckinney',
#    'lastname': 'Gallagher',
#    'age': 38,
#    'gender': 'F',
#    'address': '939 Seigel Court',
#    'employer': 'Premiant',
#    'email': 'mckinneygallagher@premiant.com',
#    'city': 'Catharine',
#    'state': 'NH'},
#   'sort': [249]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'VHRfanQBXWwj1Njs_g8_',
#   '_score': None,
#   '_source': {'account_number': 249,
#    'balance': 16822,
#    'firstname': 'Mckinney',
#    'lastname': 'Gallagher',
#    'age': 38,
#    'gender': 'F',
#    'address': '939 Seigel Court',
#    'employer': 'Premiant',
#    'email': 'mckinneygallagher@premiant.com',
#    'city': 'Catharine',
#    'state': 'NH'},
#   'sort': [249]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'JHRganQBXWwj1NjsHxcp',
#   '_score': None,
#   '_source': {'account_number': 249,
#    'balance': 16822,
#    'firstname': 'Mckinney',
#    'lastname': 'Gallagher',
#    'age': 38,
#    'gender': 'F',
#    'address': '939 Seigel Court',
#    'employer': 'Premiant',
#    'email': 'mckinneygallagher@premiant.com',
#    'city': 'Catharine',
#    'state': 'NH'},
#   'sort': [249]}]

# %%
get_n_documents(es_object, "accounts", 10, 10)
# Out:
# [{'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'YnRfanQBXWwj1Njs_Q3Z',
#   '_score': None,
#   '_source': {'account_number': 2,
#    'balance': 28838,
#    'firstname': 'Roberta',
#    'lastname': 'Bender',
#    'age': 22,
#    'gender': 'F',
#    'address': '560 Kingsway Place',
#    'employer': 'Chillium',
#    'email': 'robertabender@chillium.com',
#    'city': 'Bennett',
#    'state': 'LA'},
#   'sort': [2]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'MnRganQBXWwj1NjsHhX5',
#   '_score': None,
#   '_source': {'account_number': 2,
#    'balance': 28838,
#    'firstname': 'Roberta',
#    'lastname': 'Bender',
#    'age': 22,
#    'gender': 'F',
#    'address': '560 Kingsway Place',
#    'employer': 'Chillium',
#    'email': 'robertabender@chillium.com',
#    'city': 'Bennett',
#    'state': 'LA'},
#   'sort': [2]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'cXRYanQBXWwj1NjsoQK-',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'QnRaanQBXWwj1NjsbwqU',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'EnRfanQBXWwj1Njs_hLd',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '4nRganQBXWwj1NjsHxl5',
#   '_score': None,
#   '_source': {'account_number': 3,
#    'balance': 44947,
#    'firstname': 'Levine',
#    'lastname': 'Burks',
#    'age': 26,
#    'gender': 'F',
#    'address': '328 Wilson Avenue',
#    'employer': 'Amtap',
#    'email': 'levineburks@amtap.com',
#    'city': 'Cochranville',
#    'state': 'HI'},
#   'sort': [3]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'UXNYanQBXWwj1NjsoP-Y',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'InRaanQBXWwj1Njsbwce',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '8nRfanQBXWwj1Njs_g4_',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'wnRganQBXWwj1NjsHxYp',
#   '_score': None,
#   '_source': {'account_number': 4,
#    'balance': 27658,
#    'firstname': 'Rodriquez',
#    'lastname': 'Flores',
#    'age': 31,
#    'gender': 'F',
#    'address': '986 Wyckoff Avenue',
#    'employer': 'Tourmania',
#    'email': 'rodriquezflores@tourmania.com',
#    'city': 'Eastvale',
#    'state': 'HI'},
#   'sort': [4]}]

# %%
get_document_by_address(es_object, 'accounts', 'mill lane')
# Out:
# [{'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'h3NYanQBXWwj1NjsoP-Y',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'WHRaanQBXWwj1Njsbwce',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'KHRfanQBXWwj1Njs_g8_',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '-HRganQBXWwj1NjsHxYp',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'RXNYanQBXWwj1NjsoP-Y',
#   '_score': 5.489441,
#   '_source': {'account_number': 970,
#    'balance': 19648,
#    'firstname': 'Forbes',
#    'lastname': 'Wallace',
#    'age': 28,
#    'gender': 'M',
#    'address': '990 Mill Road',
#    'employer': 'Pheast',
#    'email': 'forbeswallace@pheast.com',
#    'city': 'Lopezo',
#    'state': 'AK'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '23NYanQBXWwj1NjsoP-Z',
#   '_score': 5.489441,
#   '_source': {'account_number': 345,
#    'balance': 9812,
#    'firstname': 'Parker',
#    'lastname': 'Hines',
#    'age': 38,
#    'gender': 'M',
#    'address': '715 Mill Avenue',
#    'employer': 'Baluba',
#    'email': 'parkerhines@baluba.com',
#    'city': 'Blackgum',
#    'state': 'KY'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'DXRYanQBXWwj1NjsoACZ',
#   '_score': 5.489441,
#   '_source': {'account_number': 472,
#    'balance': 25571,
#    'firstname': 'Lee',
#    'lastname': 'Long',
#    'age': 32,
#    'gender': 'F',
#    'address': '288 Mill Street',
#    'employer': 'Comverges',
#    'email': 'leelong@comverges.com',
#    'city': 'Movico',
#    'state': 'MT'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'FnRaanQBXWwj1Njsbwce',
#   '_score': 5.489441,
#   '_source': {'account_number': 970,
#    'balance': 19648,
#    'firstname': 'Forbes',
#    'lastname': 'Wallace',
#    'age': 28,
#    'gender': 'M',
#    'address': '990 Mill Road',
#    'employer': 'Pheast',
#    'email': 'forbeswallace@pheast.com',
#    'city': 'Lopezo',
#    'state': 'AK'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'rHRaanQBXWwj1Njsbwce',
#   '_score': 5.489441,
#   '_source': {'account_number': 345,
#    'balance': 9812,
#    'firstname': 'Parker',
#    'lastname': 'Hines',
#    'age': 38,
#    'gender': 'M',
#    'address': '715 Mill Avenue',
#    'employer': 'Baluba',
#    'email': 'parkerhines@baluba.com',
#    'city': 'Blackgum',
#    'state': 'KY'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '3nRaanQBXWwj1Njsbwce',
#   '_score': 5.489441,
#   '_source': {'account_number': 472,
#    'balance': 25571,
#    'firstname': 'Lee',
#    'lastname': 'Long',
#    'age': 32,
#    'gender': 'F',
#    'address': '288 Mill Street',
#    'employer': 'Comverges',
#    'email': 'leelong@comverges.com',
#    'city': 'Movico',
#    'state': 'MT'}}]

# %%
get_document_by_address_strict(es_object, 'accounts', 'mill lane')
# Out:
# [{'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'h3NYanQBXWwj1NjsoP-Y',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'WHRaanQBXWwj1Njsbwce',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'KHRfanQBXWwj1Njs_g8_',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '-HRganQBXWwj1NjsHxYp',
#   '_score': 9.61595,
#   '_source': {'account_number': 136,
#    'balance': 45801,
#    'firstname': 'Winnie',
#    'lastname': 'Holland',
#    'age': 38,
#    'gender': 'M',
#    'address': '198 Mill Lane',
#    'employer': 'Neteria',
#    'email': 'winnieholland@neteria.com',
#    'city': 'Urie',
#    'state': 'IL'}}]

# %%
get_document_by_age_and_state(es_object, 'accounts', 40, 'ID')
# Out:
# [{'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '7XNYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 474,
#    'balance': 35896,
#    'firstname': 'Obrien',
#    'lastname': 'Walton',
#    'age': 40,
#    'gender': 'F',
#    'address': '192 Ide Court',
#    'employer': 'Suremax',
#    'email': 'obrienwalton@suremax.com',
#    'city': 'Crucible',
#    'state': 'UT'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '73NYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 479,
#    'balance': 31865,
#    'firstname': 'Cameron',
#    'lastname': 'Ross',
#    'age': 40,
#    'gender': 'M',
#    'address': '904 Bouck Court',
#    'employer': 'Telpod',
#    'email': 'cameronross@telpod.com',
#    'city': 'Nord',
#    'state': 'MO'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'C3NYanQBXWwj1Njsnv3s',
#   '_score': 1.0,
#   '_source': {'account_number': 549,
#    'balance': 1932,
#    'firstname': 'Jacqueline',
#    'lastname': 'Maxwell',
#    'age': 40,
#    'gender': 'M',
#    'address': '444 Schenck Place',
#    'employer': 'Fuelworks',
#    'email': 'jacquelinemaxwell@fuelworks.com',
#    'city': 'Oretta',
#    'state': 'OR'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'j3NYanQBXWwj1Njsnv3t',
#   '_score': 1.0,
#   '_source': {'account_number': 878,
#    'balance': 49159,
#    'firstname': 'Battle',
#    'lastname': 'Blackburn',
#    'age': 40,
#    'gender': 'F',
#    'address': '234 Hendrix Street',
#    'employer': 'Zilphur',
#    'email': 'battleblackburn@zilphur.com',
#    'city': 'Wanamie',
#    'state': 'PA'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'k3NYanQBXWwj1Njsnv3t',
#   '_score': 1.0,
#   '_source': {'account_number': 885,
#    'balance': 31661,
#    'firstname': 'Valdez',
#    'lastname': 'Roberson',
#    'age': 40,
#    'gender': 'F',
#    'address': '227 Scholes Street',
#    'employer': 'Delphide',
#    'email': 'valdezroberson@delphide.com',
#    'city': 'Chilton',
#    'state': 'MT'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'q3NYanQBXWwj1Njsnv3t',
#   '_score': 1.0,
#   '_source': {'account_number': 948,
#    'balance': 37074,
#    'firstname': 'Sargent',
#    'lastname': 'Powers',
#    'age': 40,
#    'gender': 'M',
#    'address': '532 Fiske Place',
#    'employer': 'Accuprint',
#    'email': 'sargentpowers@accuprint.com',
#    'city': 'Umapine',
#    'state': 'AK'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'v3NYanQBXWwj1Njsnv3t',
#   '_score': 1.0,
#   '_source': {'account_number': 998,
#    'balance': 16869,
#    'firstname': 'Letha',
#    'lastname': 'Baker',
#    'age': 40,
#    'gender': 'F',
#    'address': '206 Llama Court',
#    'employer': 'Dognosis',
#    'email': 'lethabaker@dognosis.com',
#    'city': 'Dunlo',
#    'state': 'WV'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': '0XNYanQBXWwj1Njsnv3t',
#   '_score': 1.0,
#   '_source': {'account_number': 40,
#    'balance': 33882,
#    'firstname': 'Pace',
#    'lastname': 'Molina',
#    'age': 40,
#    'gender': 'M',
#    'address': '263 Ovington Court',
#    'employer': 'Cytrak',
#    'email': 'pacemolina@cytrak.com',
#    'city': 'Silkworth',
#    'state': 'OR'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'A3NYanQBXWwj1Njsnv7t',
#   '_score': 1.0,
#   '_source': {'account_number': 165,
#    'balance': 18956,
#    'firstname': 'Sims',
#    'lastname': 'Mckay',
#    'age': 40,
#    'gender': 'F',
#    'address': '205 Jackson Street',
#    'employer': 'Comtour',
#    'email': 'simsmckay@comtour.com',
#    'city': 'Tilden',
#    'state': 'DC'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'B3NYanQBXWwj1Njsnv7t',
#   '_score': 1.0,
#   '_source': {'account_number': 177,
#    'balance': 48972,
#    'firstname': 'Harris',
#    'lastname': 'Gross',
#    'age': 40,
#    'gender': 'F',
#    'address': '468 Suydam Street',
#    'employer': 'Kidstock',
#    'email': 'harrisgross@kidstock.com',
#    'city': 'Yettem',
#    'state': 'KY'}}]

# %%
get_documents_in_balance_range(es_object, 'accounts', 20000, 30000)
# Out:
# [{'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'Q3NYanQBXWwj1Njsnvzq',
#   '_score': 1.0,
#   '_source': {'account_number': 49,
#    'balance': 29104,
#    'firstname': 'Fulton',
#    'lastname': 'Holt',
#    'age': 23,
#    'gender': 'F',
#    'address': '451 Humboldt Street',
#    'employer': 'Anocha',
#    'email': 'fultonholt@anocha.com',
#    'city': 'Sunriver',
#    'state': 'RI'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'WXNYanQBXWwj1Njsnvzq',
#   '_score': 1.0,
#   '_source': {'account_number': 102,
#    'balance': 29712,
#    'firstname': 'Dena',
#    'lastname': 'Olson',
#    'age': 27,
#    'gender': 'F',
#    'address': '759 Newkirk Avenue',
#    'employer': 'Hinway',
#    'email': 'denaolson@hinway.com',
#    'city': 'Choctaw',
#    'state': 'NJ'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'ZXNYanQBXWwj1Njsnvzq',
#   '_score': 1.0,
#   '_source': {'account_number': 133,
#    'balance': 26135,
#    'firstname': 'Deena',
#    'lastname': 'Richmond',
#    'age': 36,
#    'gender': 'F',
#    'address': '646 Underhill Avenue',
#    'employer': 'Sunclipse',
#    'email': 'deenarichmond@sunclipse.com',
#    'city': 'Austinburg',
#    'state': 'SC'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'aXNYanQBXWwj1Njsnvzq',
#   '_score': 1.0,
#   '_source': {'account_number': 140,
#    'balance': 26696,
#    'firstname': 'Cotton',
#    'lastname': 'Christensen',
#    'age': 32,
#    'gender': 'M',
#    'address': '878 Schermerhorn Street',
#    'employer': 'Prowaste',
#    'email': 'cottonchristensen@prowaste.com',
#    'city': 'Mayfair',
#    'state': 'LA'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'gXNYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 203,
#    'balance': 21890,
#    'firstname': 'Eve',
#    'lastname': 'Wyatt',
#    'age': 33,
#    'gender': 'M',
#    'address': '435 Furman Street',
#    'employer': 'Assitia',
#    'email': 'evewyatt@assitia.com',
#    'city': 'Jamestown',
#    'state': 'MN'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'j3NYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 239,
#    'balance': 25719,
#    'firstname': 'Chang',
#    'lastname': 'Boyer',
#    'age': 36,
#    'gender': 'M',
#    'address': '895 Brigham Street',
#    'employer': 'Qaboos',
#    'email': 'changboyer@qaboos.com',
#    'city': 'Belgreen',
#    'state': 'NH'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'kXNYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 241,
#    'balance': 25379,
#    'firstname': 'Schroeder',
#    'lastname': 'Harrington',
#    'age': 26,
#    'gender': 'M',
#    'address': '610 Tapscott Avenue',
#    'employer': 'Otherway',
#    'email': 'schroederharrington@otherway.com',
#    'city': 'Ebro',
#    'state': 'TX'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'k3NYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 246,
#    'balance': 28405,
#    'firstname': 'Katheryn',
#    'lastname': 'Foster',
#    'age': 21,
#    'gender': 'F',
#    'address': '259 Kane Street',
#    'employer': 'Quantalia',
#    'email': 'katherynfoster@quantalia.com',
#    'city': 'Bath',
#    'state': 'TX'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'lXNYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 253,
#    'balance': 20240,
#    'firstname': 'Melissa',
#    'lastname': 'Gould',
#    'age': 31,
#    'gender': 'M',
#    'address': '440 Fuller Place',
#    'employer': 'Buzzopia',
#    'email': 'melissagould@buzzopia.com',
#    'city': 'Lumberton',
#    'state': 'MD'}},
#  {'_index': 'accounts',
#   '_type': '_doc',
#   '_id': 'n3NYanQBXWwj1Njsnvzr',
#   '_score': 1.0,
#   '_source': {'account_number': 277,
#    'balance': 29564,
#    'firstname': 'Romero',
#    'lastname': 'Lott',
#    'age': 31,
#    'gender': 'M',
#    'address': '456 Danforth Street',
#    'employer': 'Plasto',
#    'email': 'romerolott@plasto.com',
#    'city': 'Vincent',
#    'state': 'VT'}}]

# %%
aggregate_accounts_by_state(es_object, 'accounts')
# Out:
# {'took': 5, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 8000, 'relation': 'eq'}, 'max_score': None, 'hits': []}, 'aggregations': {'group_by_state': {'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 2972, 'buckets': [{'key': 'TX', 'doc_count': 120}, {'key': 'MD', 'doc_count': 112}, {'key': 'ID', 'doc_count': 108}, {'key': 'AL', 'doc_count': 100}, {'key': 'ME', 'doc_count': 100}, {'key': 'TN', 'doc_count': 100}, {'key': 'WY', 'doc_count': 100}, {'key': 'DC', 'doc_count': 96}, {'key': 'MA', 'doc_count': 96}, {'key': 'ND', 'doc_count': 96}]}}}
# {'doc_count_error_upper_bound': 0,
#  'sum_other_doc_count': 2972,
#  'buckets': [{'key': 'TX', 'doc_count': 120},
#   {'key': 'MD', 'doc_count': 112},
#   {'key': 'ID', 'doc_count': 108},
#   {'key': 'AL', 'doc_count': 100},
#   {'key': 'ME', 'doc_count': 100},
#   {'key': 'TN', 'doc_count': 100},
#   {'key': 'WY', 'doc_count': 100},
#   {'key': 'DC', 'doc_count': 96},
#   {'key': 'MA', 'doc_count': 96},
#   {'key': 'ND', 'doc_count': 96}]}
